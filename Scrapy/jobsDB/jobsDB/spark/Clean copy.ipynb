# %%
import pandas as pd
import nltk.corpus
import string
from nltk.corpus import stopwords
import json

jobs = pd.read_csv('jobsDB.csv')
data = json.load(open('keyword2.json'))

# %%
def getskills(strIn):
    liout = []
    strIn = strIn.lower()
    checker = strIn.split()
    for i in keyword_list:
        if i in checker:
            liout.append(i)
    return liout

    
stop_words = stopwords.words('english')
jobs['clean_job_description'] = jobs['job_description'].apply(lambda x: ' '.join([word.lower() for word in x.split() if word not in (stop_words)]))
# Out:
#    Unnamed: 0                                          job_title  \
# 0           0  Research Associate (Computer Science/Informati...
# 1           1                                     Linux Engineer
# 2           2  Project Manager - Management Information Syste...
# 3           3            Senior Information Systems (IT) Auditor
# 4           4  Information Technology Engineer [System Integr...
#
#                                             company  \
# 0                  Nanyang Technological University
# 1                          Horizon Manpower Service
# 2  Singapore Indian Development Association (SINDA)
# 3                         KULICKE & SOFFA PTE. LTD.
# 4                   The Supreme HR Advisory Pte Ltd
#
#                                      job_description  \
# 0  ['Carry out research in the field of recommend...
# 1  ['Proactively maintain and develop all Linux i...
# 2  ['Study, recommend and implement a cybersecuri...
# 3  ['Prepares and reviews audit planning document...
# 4  ['To perform post sales installation of produc...
#
#                                clean_job_description
# 0  ['carry research field recommendation system, ...
# 1  ['proactively maintain develop linux infrastru...
# 2  ['study, recommend implement cybersecurity man...
# 3  ['prepares reviews audit planning documents, p...
# 4  ['to perform post sales installation products/...

# %%
jobs['clean_job_description'] = jobs['clean_job_description'].str.replace('[^\w\s]','')
# Out:
#    Unnamed: 0                                          job_title  \
# 0           0  Research Associate (Computer Science/Informati...
# 1           1                                     Linux Engineer
# 2           2  Project Manager - Management Information Syste...
# 3           3            Senior Information Systems (IT) Auditor
# 4           4  Information Technology Engineer [System Integr...
#
#                                             company  \
# 0                  Nanyang Technological University
# 1                          Horizon Manpower Service
# 2  Singapore Indian Development Association (SINDA)
# 3                         KULICKE & SOFFA PTE. LTD.
# 4                   The Supreme HR Advisory Pte Ltd
#
#                                      job_description  \
# 0  ['Carry out research in the field of recommend...
# 1  ['Proactively maintain and develop all Linux i...
# 2  ['Study, recommend and implement a cybersecuri...
# 3  ['Prepares and reviews audit planning document...
# 4  ['To perform post sales installation of produc...
#
#                                clean_job_description
# 0  carry research field recommendation system tex...
# 1  proactively maintain develop linux infrastruct...
# 2  study recommend implement cybersecurity manage...
# 3  prepares reviews audit planning documents proc...
# 4  to perform post sales installation productssol...

# %%
keyword_list = data['skills']
def getskills(strIn):
    liout = []
    checker = s ztrIn.split()
    for i in keyword_list:
        if i in checker:
            liout.append(i)
    return liout
jobs['skills'] = jobs['clean_job_description'].apply(lambda x: getskills(x))

# %%
result = jobs

# %%
result.insert(loc=3, column='uppersalary', value=['' for i in range(result.shape[0])])
result.insert(loc=3, column='lowersalary', value=['' for i in range(result.shape[0])])
result.drop(result.columns[[0]], axis=1, inplace=True) 
result.drop(['job_description','clean_job_description'], axis=1, inplace=True)

# %%
result.to_parquet('cleanjobsdb.parquet')
